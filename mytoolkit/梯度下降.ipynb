# %%
import numpy as np

# %%
def fun(params, x):
    return np.dot(params.T, x)

# %%
p = np.array([[1],[2]])
len(p.shape)
# Out:
# 2

# %%
p
# Out:
# array([1, 2])

# %%
type(np.array([1,2]))
# Out:
# numpy.ndarray

# %%
p = np.array([1,2])
len(p.shape)
p
p = p[:, np.newaxis]
p
# Out:
# array([[1],
#        [2]])

# %%
x= np.array(
    [
    [4,4],
    [5,5]
])

# %%
np.dot( x,p)
# Out:
# array([[12],
#        [15]])

# %%
def to_col_vec(arr):
    if type(arr) != np.ndarray:
        raise TypeError
    elif len(arr.shape) == 1:
        arr = arr[:, np.newaxis]
    elif len(arr.shape) == 2 and arr.shape[1] != 1:
        if arr.shape[0] == 1:
            arr = arr.T
        else:
            raise ValueError
    else:
        raise ValueError
    return arr

# %%
to_col_vec(np.array([[1,2,3,4]]))
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
import matplotlib.pyplot as plt
import mglearn

x, y = mglearn.datasets.make_wave(n_samples=60)

# %%
plt.plot(x, y, 'o')
plt.ylim(-3, 3)
plt.xlabel("Feature")
plt.ylabel("Target")
# Out:
# Text(0, 0.5, 'Target')

# %%
import sys
del sys.modules['model']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-f8aa3d493312> in <module>
#       1 import sys
# ----> 2 del sys.modules['model']
#       3 from model import LinearRegressionModel
#
# KeyError: 'model'

# %%
import numpy as np
from model import LinearRegressionModel
model = LinearRegressionModel(features = x, target = y)
model.train(method = 'bgd',alpha = 0.001, max_iterations=1000, initial_params=np.array([4,4]))
# print(model.params, model.errors)
# Out:
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# (2, 1)
# (2, 1)
# (60, 2)
# ...

# %%
plt.plot(model.errors)

# %%
y_predict = model.predict(x)
print(np.sum((model.observed_y - y_predict) **2)/model.sample_num)
print(model.params, model.error)
# Out:
# 0.2871339468126629
# [[-0.05983246]
#  [ 0.42073384]] 0.2871339468126629

# %%
plt.plot(x, y, 'o')
plt.ylim(-3, 3)
plt.xlabel("Feature")
plt.ylabel("Target")
plt.plot(x, y_predict, '-')

# %%
mglearn.plots.plot_linear_regression_wave()
# Out:
# w[0]: 0.393906  b: -0.031804

# %%
import sys
del sys.modules['model']
from model import LinearRegressionModel

# %%
x = np.array([
    [152,50],
    [183,20],
    [171,20],
    [165,30],
    [158,30],
    [161,50],
    [149,60],
    [158,50],
    [170,40],
    [153,55],
    [164,40],
    [190,40],
    [185,20]
])

y = np.array([
    [120],
    [141],
    [124],
    [126],
    [117],
    [125],
    [123],
    [125],
    [132],
    [123],
    [132],
    [155],
    [147]
])

# %%
model = LinearRegressionModel(x, y)
assert (model.observed_x == x).all()
assert (model.observed_y == y).all()

# %%
model.train(method='bgd', initial_params=np.array([1,1,1]))
# Out:
# /Users/yueqi/Project/python_ml/mytoolkit/model.py:45: RuntimeWarning: overflow encountered in square
#   self.error = np.sum((np.dot(x, self.params) - self.observed_y) ** 2)/ self.sample_num
# /Users/yueqi/Project/python_ml/mytoolkit/model.py:56: RuntimeWarning: overflow encountered in double_scalars
#   self.grad[j][0] = 2 * np.sum(np.multiply(y_diff, x_j))
# /Users/yueqi/Project/python_ml/mytoolkit/model.py:56: RuntimeWarning: overflow encountered in multiply
#   self.grad[j][0] = 2 * np.sum(np.multiply(y_diff, x_j))
# /Users/yueqi/Project/python_ml/mytoolkit/model.py:58: RuntimeWarning: invalid value encountered in subtract
#   self.params = self.params - alpha * self.grad

# %%
x = np.concatenate( (np.ones((model.sample_num,1)), model.observed_x), axis = 1)
x
# Out:
# array([[  1., 152.,  50.],
#        [  1., 183.,  20.],
#        [  1., 171.,  20.],
#        [  1., 165.,  30.],
#        [  1., 158.,  30.],
#        [  1., 161.,  50.],
#        [  1., 149.,  60.],
#        [  1., 158.,  50.],
#        [  1., 170.,  40.],
#        [  1., 153.,  55.],
#        [  1., 164.,  40.],
#        [  1., 190.,  40.],
#        [  1., 185.,  20.]])

# %%
model.params = LinearRegressionModel.to_col_vec(np.array([1,1,1]))
model.params
# Out:
# array([[1],
#        [1],
#        [1]])

# %%
count = 0
converged_flag = False
epsilon = 1e-5
model.errors = []

# %%
model.error = np.sum((np.dot(x, model.params) - model.observed_y) ** 2)/ model.sample_num

# %%
model.grad = [[0] for j in range(model.params_num)]
model.grad
# Out:
# [[0], [0], [0]]

# %%
for j in range(model.params_num):
    y_diff = np.dot(x, model.params) - model.observed_y
    x_j = x[:,j][:,np.newaxis]
    model.grad[j][0] = 2 * np.sum(np.multiply(y_diff, x_j))
model.grad = np.array(model.grad)

# %%
model.grad
# Out:
# array([[  1974.],
#        [325712.],
#        [ 79660.]])

# %%
print(model.params)
model.params = model.params - 0.001 * model.grad
print(model.params)
# Out:
# [[1]
#  [1]
#  [1]]
# [[  -0.974]
#  [-324.712]
#  [ -78.66 ]]

# %%
    x = np.array([
        [152,50],
        [183,20],
        [171,20],
        [165,30],
        [158,30],
        [161,50],
        [149,60],
        [158,50],
        [170,40],
        [153,55],
        [164,40],
        [190,40],
        [185,20]
    ])

    y = np.array([
        [120],
        [141],
        [124],
        [126],
        [117],
        [125],
        [123],
        [125],
        [132],
        [123],
        [132],
        [155],
        [147]
    ])

    model = LinearRegressionModel(x, y)
    assert (model.observed_x == x).all()
    assert (model.observed_y == y).all()

    model.train(method='bgd',alpha=1e-7, max_iterations=100000, initial_params=np.array([100,1,1]))
    print(model.params)
    import matplotlib.pyplot as plt
    plt.plot(model.errors)
# Out:
# [[99.89954531]
#  [ 0.23705607]
#  [-0.22952336]]

# %%
    plt.plot(model.errors[-100:])

# %%
    plt.plot(model.errors[-10:])

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import mglearn

x, y = mglearn.datasets.make_wave(n_samples=60)

# %%
features = x
target = y

# %%
regression = LinearRegression()

# %%
model = regression.fit(features, target)

# %%
model.coef_
# Out:
# array([0.42073384])

# %%
model.intercept_
# Out:
# -0.05983245830361801
